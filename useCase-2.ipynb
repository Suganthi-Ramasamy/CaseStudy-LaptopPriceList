# %%
import pandas as pd
pricelist = pd.read_table('C:/Users/Suganthi_Ramasamy/OneDrive - Dell Technologies/Desktop/DS/Data/Pricelist.csv', sep=",")
pricelist.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn  ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th       4     DDR4
# 1  Lenovo           Intel        Core i3            10th       4     DDR4
# 2  Lenovo           Intel        Core i3            10th       4     DDR4
# 3    ASUS           Intel        Core i5            10th       8     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available       4     DDR4
#
#    ssd_gb   hdd       os  os_bit  graphic_card_gb  weight     warranty  \
# 0       0  1024  Windows  64-bit                0  Casual  No warranty
# 1       0  1024  Windows  64-bit                0  Casual  No warranty
# 2       0  1024  Windows  64-bit                0  Casual  No warranty
# 3     512     0  Windows  32-bit                2  Casual  No warranty
# 4       0   512  Windows  64-bit                0  Casual  No warranty
#
#   Touchscreen msoffice  Price  rating_by_stars  Number of Ratings  \
# ...

# %%
pricelist[pricelist['brand'] == 'HP'].shape
# Out:
# (136, 19)

# %%
pricelist[pricelist['brand'] == 'DELL'].shape
# Out:
# (151, 19)

# %%
pricelist[pricelist['brand'] == 'ASUS'].shape
# Out:
# (249, 19)

# %%
cols = ['brand','ram_gb', 'ssd_gb']
pricelist[(pricelist.ram_gb >= 8 ) & (pricelist.ssd_gb >= 256)][cols]
# Out:
#       brand  ram_gb  ssd_gb
# 3      ASUS       8     512
# 15       HP       8     256
# 16       HP       8     256
# 18       HP       8     256
# 25   Lenovo       8     256
# ..      ...     ...     ...
# 798    ASUS      16    1024
# 799    ASUS      16    1024
# 800    ASUS      16    1024
# 801    ASUS      16    1024
# 822  Lenovo       8     512
#
# [531 rows x 3 columns]

# %%
#Sorting by price in ascenrding order
pricelist.sort_values(by='Price', ascending=True).head()
# Out:
#       brand processor_brand processor_name processor_gnrtn  ram_gb ram_type  \
# 194  Lenovo           Intel   Celeron Dual   Not Available       4   LPDDR4
# 12    Avita           Intel   Celeron Dual   Not Available       4     DDR4
# 189    ASUS           Intel   Celeron Dual   Not Available       4   LPDDR4
# 188    ASUS           Intel   Celeron Dual   Not Available       4   LPDDR4
# 170    ASUS           Intel   Celeron Dual   Not Available       4   LPDDR4
#
#      ssd_gb  hdd       os  os_bit  graphic_card_gb  weight     warranty  \
# 194       0  512  Windows  32-bit                0  Casual  No warranty
# 12        0  512  Windows  64-bit                0  Casual  No warranty
# 189       0  512  Windows  32-bit                0  Casual  No warranty
# 188       0  512  Windows  64-bit                0  Casual  No warranty
# 170       0  512  Windows  32-bit                0  Casual  No warranty
#
#     Touchscreen msoffice  Price  rating_by_stars  Number of Ratings  \
# ...

# %%
#Sorting by price in descending order
pricelist.sort_values(by='Price', ascending=False).head()
# Out:
#      brand processor_brand processor_name processor_gnrtn  ram_gb ram_type  \
# 594   ASUS           Intel        Core i9            11th      16     DDR4
# 621  APPLE              M1             M1            10th      32     DDR4
# 590   ASUS           Intel        Core i9            12th      16     DDR5
# 433    MSI           Intel        Core i5            10th       8   LPDDR4
# 547    MSI           Intel        Core i7            12th      16     DDR5
#
#      ssd_gb  hdd       os  os_bit  graphic_card_gb  weight     warranty  \
# 594    3072    0  Windows  32-bit                6  Casual       1 year
# 621    1024    0      Mac  64-bit                0  Casual       1 year
# 590    1024    0  Windows  64-bit                6  Casual  No warranty
# 433       0  512      DOS  32-bit                6  Casual  No warranty
# 547    1024    0  Windows  64-bit                8  Casual  No warranty
#
#     Touchscreen msoffice   Price  rating_by_stars  Number of Ratings  \
# ...

# %%
pricelist[pricelist['Touchscreen'] == 'Yes'].shape
# Out:
# (97, 19)

# %%
col1 = ['brand','ram_gb', 'Touchscreen']
pricelist[(pricelist.brand == 'HP') & (pricelist.ram_gb >= 8) & (pricelist.Touchscreen == 'Yes')][col1]
# Out:
#     brand  ram_gb Touchscreen
# 15     HP       8         Yes
# 30     HP       8         Yes
# 129    HP       8         Yes
# 211    HP       8         Yes
# 252    HP       8         Yes
# 322    HP       8         Yes
# 330    HP       8         Yes
# 333    HP       8         Yes
# 361    HP       8         Yes
# 363    HP       8         Yes
# 369    HP       8         Yes
# 497    HP      16         Yes
# 500    HP      16         Yes
# 507    HP      16         Yes
# 513    HP      16         Yes
# 519    HP      16         Yes
# 543    HP      16         Yes
# 552    HP      16         Yes
# 558    HP      16         Yes
# 569    HP      16         Yes
# 692    HP      16         Yes
# 697    HP       8         Yes
# 776    HP      16         Yes

# %%
col1 = ['brand','ram_gb', 'Touchscreen']
pricelist[(pricelist.brand == 'HP') & (pricelist.ram_gb >= 8) & (pricelist.Touchscreen == 'Yes')][col1].shape
# Out:
# (23, 3)
